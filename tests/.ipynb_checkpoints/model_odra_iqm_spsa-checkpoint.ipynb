# %% [markdown]
# # IQM fine-tuning experiment (SPSA)
#
# This notebook supports a simple **hypothesis**:
#
# > **Weights trained only with a noiseless `StatevectorEstimator` are not optimal for IQM shot-based readout.**
# > **SPSA fine-tuning on the real IQM objective** can **improve full-test IQM metrics** vs those same SV-trained weights.
#
# **Protocol**
#
# 1. **Phase A — Statevector baseline:** SPSA on exact MSE, using only the **fit** subset of training data (a **validation** slice is held out for IQM monitoring).
# 2. **Phase B — IQM test (before):** **Repeated** full-test jobs on IQM → report **mean ± std** for loss / acc / binary F1 / **macro F1**; confusion matrix from **averaged** ⟨Z⟩ over repeats.
# 3. **Phase C — IQM fine-tuning:** SPSA with **IQM shot MSE** on fit subset; **larger minibatches** and **SPSA `resamplings`** (and optional **2-SPSA**). After each **outer** epoch, **repeated IQM validation**; **early stopping** if the monitored metric does not improve.
# 4. **Phase D — IQM test (after):** Same repeated evaluation and comparison.
#
# **Strengthening knobs (large-budget defaults in config):** `SHOTS`, `IQM_TEST_REPEATS`, `VAL_EVAL_REPEATS`, Phase C size, `SV_SPSA_RESAMPLINGS` / `IQM_FT_SPSA_RESAMPLINGS`, `*_SPSA_SECOND_ORDER`, early stopping.
#
# **Controls**
#
# - `SMOKE_TEST = True`: no IQM; repeated evals are deterministic (std 0).
# - **Security:** `IQM_TOKEN` via environment variable; clear outputs before sharing.

# %% [markdown]
# ## Configuration

# %%
import os
from pathlib import Path


def find_repo_root() -> Path:
    p = Path.cwd().resolve()
    for cand in [p, *p.parents]:
        if (cand / "pyproject.toml").exists():
            return cand
    return p


REPO_ROOT = find_repo_root()

# True = no IQM connection; IQM metrics use statevector proxy (repeats collapse to identical samples).
SMOKE_TEST = True

IQM_URL = os.environ.get("IQM_SERVER_URL", "https://odra5.e-science.pl/")
IQM_TOKEN = os.environ.get("IQM_TOKEN")

NUM_QUBITS = 5
ANSATZ_DEPTH = 2
RANDOM_SEED = 42

# --- IQM shot budget (raise further if you want lower-variance estimates) ---
SHOTS = 4096 if not SMOKE_TEST else None

# Repeated full-dataset IQM evaluations (mean ± std). Each repeat = full batched job(s) over all circuits.
IQM_TEST_REPEATS = 5
# Validation repeats per early-stop check (smaller than test to save time).
VAL_EVAL_REPEATS = 3

# Held-out fraction of *training* rows for IQM validation during Phase C (test set stays locked).
VAL_FRACTION = 0.15

# --- Phase A: statevector SPSA ---
SV_OUTER_EPOCHS = 4
SV_MINIBATCHES_PER_EPOCH = 4
SV_MINIBATCH_SIZE = 24
SV_SPSA_MAXITER = 12
SV_SPSA_LEARNING_RATE = 0.12
SV_SPSA_PERTURBATION = 0.06
SV_SPSA_RESAMPLINGS = 1
SV_SPSA_SECOND_ORDER = False

# --- Phase C: IQM fine-tuning (large budget; early stop trims if no val gain) ---
IQM_FT_MAX_OUTER_EPOCHS = 24
IQM_FT_MINIBATCHES_PER_EPOCH = 6
IQM_FT_MINIBATCH_SIZE = 48
IQM_FT_SPSA_MAXITER = 10
IQM_FT_SPSA_LEARNING_RATE = 0.08
IQM_FT_SPSA_PERTURBATION = 0.05
IQM_FT_SPSA_RESAMPLINGS = 2
IQM_FT_SPSA_SECOND_ORDER = False

# Early stopping on repeated IQM validation (after each outer epoch of Phase C)
EARLY_STOP_PATIENCE = 5
EARLY_STOP_MIN_DELTA = 0.005
# "acc" or "f1_macro" (binary F1 for class +1 is "f1")
EARLY_STOP_MONITOR = "f1_macro"

# Full test IQM eval chunking (None = one job with all circuits)
TEST_EVAL_CHUNK = None

WEIGHTS_SV = REPO_ROOT / "tests" / "model_odra_iqm_exp_weights_sv.npy"
WEIGHTS_FINAL = REPO_ROOT / "tests" / "model_odra_iqm_exp_weights_after_iqm_ft.npy"

# %% [markdown]
# ## Imports

# %%
import random
from datetime import datetime, timezone

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score, confusion_matrix, f1_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from ucimlrepo import fetch_ucirepo

from qiskit import QuantumCircuit, transpile
from qiskit.circuit import ParameterVector
from qiskit.primitives import StatevectorEstimator, PrimitiveResult, PubResult
from qiskit.primitives.base import BaseEstimatorV2
from qiskit.primitives.containers.data_bin import DataBin
from qiskit.quantum_info import SparsePauliOp
from qiskit_machine_learning.neural_networks import EstimatorQNN
from qiskit_algorithms.optimizers import SPSA
from qiskit_algorithms.utils import algorithm_globals

from iqm.qiskit_iqm import IQMProvider

# %% [markdown]
# ## Data and circuits (same as `models/model_odra.ipynb`)

# %%
def set_random_seed(seed: int = 42) -> None:
    random.seed(seed)
    np.random.seed(seed)
    algorithm_globals.random_seed = seed


set_random_seed(RANDOM_SEED)


def prepare_data(test_size: float = 0.2, random_state: int = 42):
    banknote_authentication = fetch_ucirepo(id=267)
    X = banknote_authentication.data.features.to_numpy()
    y = banknote_authentication.data.targets.to_numpy().ravel()

    assert X.shape[1] == 4
    assert set(np.unique(y)) == {0, 1}

    variance = X[:, 0].reshape(-1, 1)
    skewness = X[:, 1].reshape(-1, 1)
    interaction = variance * skewness
    X_expanded = np.hstack((X, interaction))

    X_train, X_test, y_train, y_test = train_test_split(
        X_expanded, y, test_size=test_size, random_state=random_state
    )

    scaler = MinMaxScaler(feature_range=(-np.pi / 4, np.pi / 4))
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    return X_train_scaled, X_test_scaled, y_train, y_test


def ansatz(n_qubits, depth):
    params_per_iter = 4 * n_qubits
    theta = ParameterVector("θ", params_per_iter * (depth // 2))
    qc = QuantumCircuit(n_qubits)
    for j in range(depth // 2):
        offset = j * params_per_iter
        for i in range(n_qubits):
            qc.ry(theta[offset + i], i)
        for i in range(n_qubits):
            control, target = i, (i + 1) % n_qubits
            param_idx = offset + n_qubits + i
            qc.rz(theta[param_idx], target)
            qc.cz(control, target)
        offset_l2 = offset + 2 * n_qubits
        for i in range(n_qubits):
            qc.rx(theta[offset_l2 + i], i)
        for i in range(n_qubits):
            control, target = i, (i - 1) % n_qubits
            param_idx = offset_l2 + n_qubits + i
            qc.ry(theta[param_idx], target)
            qc.cz(control, target)
    return qc


def create_angle_encoding(num_qubits: int) -> QuantumCircuit:
    qc_data = QuantumCircuit(num_qubits)
    input_params = ParameterVector("x", num_qubits)
    for i in range(num_qubits):
        qc_data.ry(input_params[i], i)
    return qc_data


class SimpleIQMJob:
    def __init__(self, result):
        self._result = result

    def result(self):
        return self._result


class IQMBackendEstimator(BaseEstimatorV2):
    '''Z readout on qubit 0 from measured bitstrings (same as `model_odra.ipynb`).'''

    def __init__(self, backend, options=None):
        super().__init__()
        self._backend = backend
        self._options = options or {"shots": 100}

    def run(self, pubs, precision=None):
        if not isinstance(pubs, list):
            pubs = [pubs]
        job_results = []

        base_circuit = pubs[0][0]
        circuit_with_meas = base_circuit.copy()
        if circuit_with_meas.num_clbits == 0:
            circuit_with_meas.measure_all()

        transpiled_qc = transpile(circuit_with_meas, self._backend, optimization_level=0)

        for pub in pubs:
            _, _obs, parameter_values = pub
            if parameter_values.ndim == 1:
                parameter_values = [parameter_values]

            pub_expectations = []
            for params in parameter_values:
                bound_qc = transpiled_qc.assign_parameters(params)
                try:
                    job = self._backend.run(bound_qc, shots=self._options["shots"])
                    result = job.result()
                    counts = result.get_counts()
                    if isinstance(counts, list):
                        counts = counts[0]
                    shots = sum(counts.values())
                    count_0 = sum(c for bitstring, c in counts.items() if bitstring[-1] == "0")
                    p0 = count_0 / shots
                    pub_expectations.append(2 * p0 - 1)
                except Exception as e:
                    print(f"Job failed: {e}")
                    pub_expectations.append(0.0)

            data = DataBin(evs=np.array(pub_expectations), shape=(len(pub_expectations),))
            job_results.append(PubResult(data=data))

        return SimpleIQMJob(PrimitiveResult(job_results))

# %% [markdown]
# ## Build circuit, `qnn_sv`, and IQM backend

# %%
hw_feature_map = create_angle_encoding(NUM_QUBITS)
hw_ansatz = ansatz(NUM_QUBITS, ANSATZ_DEPTH)

hw_qc = QuantumCircuit(NUM_QUBITS)
hw_qc.compose(hw_feature_map, qubits=range(NUM_QUBITS), inplace=True)
hw_qc.compose(hw_ansatz, inplace=True)

observable = SparsePauliOp.from_list([("I" * (NUM_QUBITS - 1) + "Z", 1)])

qnn_sv = EstimatorQNN(
    circuit=hw_qc,
    observables=observable,
    input_params=list(hw_feature_map.parameters),
    weight_params=list(hw_ansatz.parameters),
    estimator=StatevectorEstimator(),
)

SESSION_T_UTC = datetime.now(timezone.utc).strftime("%Y-%m-%d %H:%M:%S UTC")
print("Notebook session timestamp (protocol hygiene):", SESSION_T_UTC)

iqm_backend = None
if SMOKE_TEST:
    print("SMOKE_TEST=True: skipping IQM provider; IQM phases will use statevector proxy.")
else:
    token = IQM_TOKEN or input("Enter IQM Token: ")
    provider = IQMProvider(IQM_URL, token=token)
    iqm_backend = provider.get_backend()
    print(f"Connected to backend: {iqm_backend.name} at {SESSION_T_UTC}")

hw_qc_measured = hw_qc.copy()
if hw_qc_measured.num_clbits == 0:
    hw_qc_measured.measure_all()

iqm_transpiled_template = None
if iqm_backend is not None:
    iqm_transpiled_template = transpile(hw_qc_measured, iqm_backend, optimization_level=0)

print("num_weights:", qnn_sv.num_weights)
# Out:
# WARNING:qiskit_machine_learning.neural_networks.estimator_qnn:No gradient function provided, creating a gradient function. If your Estimator requires transpilation, please provide a pass manager.
# Notebook session timestamp (protocol hygiene): 2026-03-22 14:31:40 UTC
# SMOKE_TEST=True: skipping IQM provider; IQM phases will use statevector proxy.
# num_weights: 20

# %% [markdown]
# ## Helpers: forward, batched IQM dataset eval, SPSA phase

# %%
X_train, X_test, y_train_raw, y_test_raw = prepare_data(
    test_size=0.2, random_state=RANDOM_SEED
)
y_train = (2 * y_train_raw - 1).astype(np.float64)
y_test = (2 * y_test_raw - 1).astype(np.float64)

# Fit pool vs IQM validation (from training only; test never touched during tuning)
_strat = (y_train > 0).astype(np.int32)
X_train_fit, X_val, y_train_fit, y_val = train_test_split(
    X_train,
    y_train,
    test_size=VAL_FRACTION,
    random_state=RANDOM_SEED + 7,
    stratify=_strat,
)
print(
    f"Data: train_fit={len(X_train_fit)} val={len(X_val)} test={len(X_test)} "
    f"(VAL_FRACTION={VAL_FRACTION})"
)


def predict_raw_sv(theta: np.ndarray, X: np.ndarray) -> np.ndarray:
    theta = np.asarray(theta, dtype=float).ravel()
    out = []
    for i in range(X.shape[0]):
        v = qnn_sv.forward(X[i : i + 1], theta)
        out.append(float(np.asarray(v, dtype=float).ravel()[0]))
    return np.asarray(out, dtype=float)


def metrics_from_preds(preds: np.ndarray, y: np.ndarray) -> dict:
    y = np.asarray(y, dtype=float).ravel()
    cls_pred = np.where(preds > 0, 1, -1)
    return {
        "loss": float(np.mean((preds - y) ** 2)),
        "acc": float(accuracy_score(y, cls_pred)),
        "f1": float(f1_score(y, cls_pred, pos_label=1)),
        "f1_macro": float(
            f1_score(y, cls_pred, labels=[-1, 1], average="macro", zero_division=0)
        ),
        "cls_pred": cls_pred,
        "preds": preds,
    }


def _z0_expectation_from_counts(counts: dict) -> float:
    shots = sum(counts.values())
    if shots == 0:
        return 0.0
    count_0 = sum(c for bitstring, c in counts.items() if bitstring[-1] == "0")
    return float(2 * count_0 / shots - 1)


def _normalize_counts_list(result) -> list[dict]:
    raw = result.get_counts()
    if isinstance(raw, dict):
        return [raw]
    return list(raw)


def _evaluate_iqm_single_pass(
    weights: np.ndarray,
    X_arr: np.ndarray,
    y_arr: np.ndarray,
    label: str,
) -> dict:
    '''One full pass over X_arr on IQM (or SV proxy).'''
    w = np.asarray(weights, dtype=float).ravel()
    if SMOKE_TEST or iqm_transpiled_template is None:
        preds = predict_raw_sv(w, X_arr)
        m = metrics_from_preds(preds, y_arr)
        m["note"] = "proxy: StatevectorEstimator"
        return m

    n = X_arr.shape[0]
    chunk = TEST_EVAL_CHUNK if TEST_EVAL_CHUNK is not None else n
    all_counts: list[dict] = []
    for start in range(0, n, chunk):
        stop = min(start + chunk, n)
        bound = []
        for i in range(start, stop):
            vals = np.concatenate([X_arr[i], w])
            bound.append(iqm_transpiled_template.assign_parameters(vals))
        print(f"  {label}: circuits {start}..{stop - 1} ({len(bound)}), shots={SHOTS}")
        job = iqm_backend.run(bound, shots=int(SHOTS))
        res = job.result()
        all_counts.extend(_normalize_counts_list(res))

    preds = np.array([_z0_expectation_from_counts(c) for c in all_counts], dtype=float)
    m = metrics_from_preds(preds, y_arr)
    m["note"] = "IQM hardware"
    return m


def evaluate_iqm_repeated(
    weights: np.ndarray,
    X_arr: np.ndarray,
    y_arr: np.ndarray,
    label: str,
    n_repeats: int,
) -> dict:
    '''n_repeats independent full evaluations; report mean±std; confusion from mean ⟨Z⟩.'''
    y_arr = np.asarray(y_arr, dtype=float)
    losses, accs, f1s, f1ms = [], [], [], []
    pred_stack = []

    for r in range(n_repeats):
        m = _evaluate_iqm_single_pass(
            weights, X_arr, y_arr, f"{label} repeat {r + 1}/{n_repeats}"
        )
        losses.append(m["loss"])
        accs.append(m["acc"])
        f1s.append(m["f1"])
        f1ms.append(m["f1_macro"])
        pred_stack.append(m["preds"])
        print(
            f"    -> loss={m['loss']:.6f} acc={m['acc']:.4f} f1={m['f1']:.4f} "
            f"f1_macro={m['f1_macro']:.4f} [{m['note']}]"
        )

    pred_mean = np.mean(np.stack(pred_stack, axis=0), axis=0)
    agg = metrics_from_preds(pred_mean, y_arr)
    out = {
        "loss_mean": float(np.mean(losses)),
        "loss_std": float(np.std(losses, ddof=1)) if len(losses) > 1 else 0.0,
        "acc_mean": float(np.mean(accs)),
        "acc_std": float(np.std(accs, ddof=1)) if len(accs) > 1 else 0.0,
        "f1_mean": float(np.mean(f1s)),
        "f1_std": float(np.std(f1s, ddof=1)) if len(f1s) > 1 else 0.0,
        "f1_macro_mean": float(np.mean(f1ms)),
        "f1_macro_std": float(np.std(f1ms, ddof=1)) if len(f1ms) > 1 else 0.0,
        "cls_pred": agg["cls_pred"],
        "preds": pred_mean,
    }
    # expose scalar keys compatible with older summary table
    out["loss"] = out["loss_mean"]
    out["acc"] = out["acc_mean"]
    out["f1"] = out["f1_mean"]
    out["f1_macro"] = out["f1_macro_mean"]
    if SMOKE_TEST or iqm_transpiled_template is None:
        out["note"] = "proxy: StatevectorEstimator (repeated runs identical)"
    else:
        out["note"] = f"IQM hardware ({n_repeats} repeats)"

    print(
        f"{label} AGG mean±std: loss={out['loss_mean']:.6f}±{out['loss_std']:.6f} "
        f"acc={out['acc_mean']:.4f}±{out['acc_std']:.4f} f1={out['f1_mean']:.4f}±{out['f1_std']:.4f} "
        f"f1_macro={out['f1_macro_mean']:.4f}±{out['f1_macro_std']:.4f}"
    )
    return out


def mse_minibatch_statevector(theta: np.ndarray, X: np.ndarray, y: np.ndarray) -> float:
    preds = predict_raw_sv(theta, X)
    return float(np.mean((preds - y) ** 2))


def mse_minibatch_iqm(theta: np.ndarray, X: np.ndarray, y: np.ndarray) -> float:
    if SMOKE_TEST:
        return mse_minibatch_statevector(theta, X, y)
    w = np.asarray(theta, dtype=float).ravel()
    bound = []
    for i in range(X.shape[0]):
        vals = np.concatenate([X[i], w])
        bound.append(iqm_transpiled_template.assign_parameters(vals))
    job = iqm_backend.run(bound, shots=int(SHOTS))
    res = job.result()
    counts_list = _normalize_counts_list(res)
    preds = np.array([_z0_expectation_from_counts(c) for c in counts_list], dtype=float)
    yv = np.asarray(y, dtype=float).ravel()
    return float(np.mean((preds - yv) ** 2))


def run_spsa_phase(
    weights_init: np.ndarray,
    rng: np.random.Generator,
    train_mode: str,
    n_outer_epochs: int,
    minibatches_per_epoch: int,
    minibatch_size: int,
    spsa_maxiter: int,
    lr: float,
    pert: float,
    phase_name: str,
    X_pool: np.ndarray,
    y_pool: np.ndarray,
    resamplings: int = 1,
    second_order: bool = False,
) -> np.ndarray:
    assert train_mode in ("statevector", "iqm")
    weights = np.asarray(weights_init, dtype=float).ravel().copy()
    loss_fn = mse_minibatch_statevector if train_mode == "statevector" else mse_minibatch_iqm

    for ep in range(n_outer_epochs):
        for mb in range(minibatches_per_epoch):
            idx = rng.choice(
                X_pool.shape[0],
                size=min(minibatch_size, X_pool.shape[0]),
                replace=False,
            )
            Xb = X_pool[idx]
            yb = y_pool[idx]
            tag = f"{phase_name} | outer {ep + 1}/{n_outer_epochs} mb {mb + 1}/{minibatches_per_epoch} ({train_mode})"

            def objective(theta):
                return loss_fn(theta, Xb, yb)

            step = {"k": 0}

            def cb(nfev, parameters, value, stepsize, accepted):
                step["k"] += 1
                lv = float(np.asarray(value, dtype=float).ravel()[0])
                print(f"  {tag} SPSA {step['k']}/{spsa_maxiter}: loss={lv:.6f} nfev={nfev}")

            opt = SPSA(
                maxiter=spsa_maxiter,
                learning_rate=lr,
                perturbation=pert,
                resamplings=resamplings,
                second_order=second_order,
                callback=cb,
            )
            r = opt.minimize(objective, weights)
            weights = np.asarray(r.x, dtype=float).ravel()
            print(f"  {tag} done nit={r.nit} nfev={r.nfev}")

    return weights


def run_iqm_finetune_early_stop(
    weights_init: np.ndarray,
    rng: np.random.Generator,
) -> tuple[np.ndarray, dict]:
    '''Phase C with IQM validation and patience-based early stopping.'''
    weights = np.asarray(weights_init, dtype=float).ravel().copy()
    best_w = weights.copy()
    best_score = -1.0
    patience_left = EARLY_STOP_PATIENCE
    history = []

    for ep in range(IQM_FT_MAX_OUTER_EPOCHS):
        tag_prefix = f"Phase C (IQM FT) outer {ep + 1}/{IQM_FT_MAX_OUTER_EPOCHS}"
        print(f"\n=== {tag_prefix} ===")

        for mb in range(IQM_FT_MINIBATCHES_PER_EPOCH):
            idx = rng.choice(
                X_train_fit.shape[0],
                size=min(IQM_FT_MINIBATCH_SIZE, X_train_fit.shape[0]),
                replace=False,
            )
            Xb = X_train_fit[idx]
            yb = y_train_fit[idx]
            tag = f"{tag_prefix} mb {mb + 1}/{IQM_FT_MINIBATCHES_PER_EPOCH}"

            def objective(theta):
                return mse_minibatch_iqm(theta, Xb, yb)

            step = {"k": 0}

            def cb(nfev, parameters, value, stepsize, accepted):
                step["k"] += 1
                lv = float(np.asarray(value, dtype=float).ravel()[0])
                print(f"  {tag} SPSA {step['k']}/{IQM_FT_SPSA_MAXITER}: loss={lv:.6f} nfev={nfev}")

            opt = SPSA(
                maxiter=IQM_FT_SPSA_MAXITER,
                learning_rate=IQM_FT_SPSA_LEARNING_RATE,
                perturbation=IQM_FT_SPSA_PERTURBATION,
                resamplings=IQM_FT_SPSA_RESAMPLINGS,
                second_order=IQM_FT_SPSA_SECOND_ORDER,
                callback=cb,
            )
            r = opt.minimize(objective, weights)
            weights = np.asarray(r.x, dtype=float).ravel()
            print(f"  {tag} done nit={r.nit} nfev={r.nfev}")

        val = evaluate_iqm_repeated(
            weights,
            X_val,
            y_val,
            f"{tag_prefix} IQM val",
            n_repeats=VAL_EVAL_REPEATS,
        )
        if EARLY_STOP_MONITOR == "acc":
            score = val["acc_mean"]
        else:
            score = val["f1_macro_mean"]

        history.append({"epoch": ep + 1, "val_acc": val["acc_mean"], "val_f1_macro": val["f1_macro_mean"]})

        improved = score > best_score + EARLY_STOP_MIN_DELTA
        if improved:
            best_score = score
            best_w = weights.copy()
            patience_left = EARLY_STOP_PATIENCE
            print(f"  Early-stop: new best {EARLY_STOP_MONITOR}={score:.6f} (saved weights)")
        else:
            patience_left -= 1
            print(
                f"  Early-stop: no improvement ({EARLY_STOP_MONITOR}={score:.6f} vs best {best_score:.6f}), "
                f"patience {patience_left}/{EARLY_STOP_PATIENCE}"
            )

        if patience_left <= 0:
            print("Early stopping Phase C.")
            break

    return best_w, {"best_score": best_score, "monitor": EARLY_STOP_MONITOR, "history": history}
# Out:
# Data: train_fit=932 val=165 test=275 (VAL_FRACTION=0.15)

# %% [markdown]
# ## Phase A — Train with SPSA on `StatevectorEstimator` (baseline weights)

# %%
rng = np.random.default_rng(RANDOM_SEED)
weights0 = rng.uniform(-0.2, 0.2, qnn_sv.num_weights)

weights_sv = run_spsa_phase(
    weights0,
    rng,
    train_mode="statevector",
    n_outer_epochs=SV_OUTER_EPOCHS,
    minibatches_per_epoch=SV_MINIBATCHES_PER_EPOCH,
    minibatch_size=SV_MINIBATCH_SIZE,
    spsa_maxiter=SV_SPSA_MAXITER,
    lr=SV_SPSA_LEARNING_RATE,
    pert=SV_SPSA_PERTURBATION,
    phase_name="Phase A (SV)",
    X_pool=X_train_fit,
    y_pool=y_train_fit,
    resamplings=SV_SPSA_RESAMPLINGS,
    second_order=SV_SPSA_SECOND_ORDER,
)

np.save(WEIGHTS_SV, weights_sv)
print("Saved statevector-trained weights to", WEIGHTS_SV)

metrics_sv_test_exact = metrics_from_preds(predict_raw_sv(weights_sv, X_test), y_test)
print(
    "Statevector snapshot on test (exact): "
    f"loss={metrics_sv_test_exact['loss']:.6f} acc={metrics_sv_test_exact['acc']:.4f} "
    f"f1={metrics_sv_test_exact['f1']:.4f} f1_macro={metrics_sv_test_exact['f1_macro']:.4f}"
)
# Out:
#   Phase A (SV) | outer 1/4 mb 1/4 (statevector) SPSA 1/12: loss=1.617574 nfev=3
#   Phase A (SV) | outer 1/4 mb 1/4 (statevector) SPSA 2/12: loss=1.601789 nfev=6
#   Phase A (SV) | outer 1/4 mb 1/4 (statevector) SPSA 3/12: loss=1.241389 nfev=9
#   Phase A (SV) | outer 1/4 mb 1/4 (statevector) SPSA 4/12: loss=1.226635 nfev=12
#   Phase A (SV) | outer 1/4 mb 1/4 (statevector) SPSA 5/12: loss=1.228905 nfev=15
#   Phase A (SV) | outer 1/4 mb 1/4 (statevector) SPSA 6/12: loss=0.770774 nfev=18
#   Phase A (SV) | outer 1/4 mb 1/4 (statevector) SPSA 7/12: loss=0.737167 nfev=21
#   Phase A (SV) | outer 1/4 mb 1/4 (statevector) SPSA 8/12: loss=0.725809 nfev=24
#   Phase A (SV) | outer 1/4 mb 1/4 (statevector) SPSA 9/12: loss=0.714306 nfev=27
#   Phase A (SV) | outer 1/4 mb 1/4 (statevector) SPSA 10/12: loss=0.722841 nfev=30
#   Phase A (SV) | outer 1/4 mb 1/4 (statevector) SPSA 11/12: loss=0.720016 nfev=33
#   Phase A (SV) | outer 1/4 mb 1/4 (statevector) SPSA 12/12: loss=0.715114 nfev=36
#   Phase A (SV) | outer 1/4 mb 1/4 (statevector) done nit=12 nfev=36
#   Phase A (SV) | outer 1/4 mb 2/4 (statevector) SPSA 1/12: loss=0.653946 nfev=3
#   Phase A (SV) | outer 1/4 mb 2/4 (statevector) SPSA 2/12: loss=0.652950 nfev=6
#   Phase A (SV) | outer 1/4 mb 2/4 (statevector) SPSA 3/12: loss=0.639546 nfev=9
#   Phase A (SV) | outer 1/4 mb 2/4 (statevector) SPSA 4/12: loss=0.651203 nfev=12
#   Phase A (SV) | outer 1/4 mb 2/4 (statevector) SPSA 5/12: loss=0.651245 nfev=15
#   Phase A (SV) | outer 1/4 mb 2/4 (statevector) SPSA 6/12: loss=0.644149 nfev=18
#   Phase A (SV) | outer 1/4 mb 2/4 (statevector) SPSA 7/12: loss=0.645233 nfev=21
#   Phase A (SV) | outer 1/4 mb 2/4 (statevector) SPSA 8/12: loss=0.640080 nfev=24
#   Phase A (SV) | outer 1/4 mb 2/4 (statevector) SPSA 9/12: loss=0.635176 nfev=27
#   Phase A (SV) | outer 1/4 mb 2/4 (statevector) SPSA 10/12: loss=0.635623 nfev=30
#   Phase A (SV) | outer 1/4 mb 2/4 (statevector) SPSA 11/12: loss=0.628777 nfev=33
#   Phase A (SV) | outer 1/4 mb 2/4 (statevector) SPSA 12/12: loss=0.633771 nfev=36
#   Phase A (SV) | outer 1/4 mb 2/4 (statevector) done nit=12 nfev=36
#   Phase A (SV) | outer 1/4 mb 3/4 (statevector) SPSA 1/12: loss=0.640616 nfev=3
#   Phase A (SV) | outer 1/4 mb 3/4 (statevector) SPSA 2/12: loss=0.636665 nfev=6
#   Phase A (SV) | outer 1/4 mb 3/4 (statevector) SPSA 3/12: loss=0.646815 nfev=9
#   Phase A (SV) | outer 1/4 mb 3/4 (statevector) SPSA 4/12: loss=0.629962 nfev=12
#   Phase A (SV) | outer 1/4 mb 3/4 (statevector) SPSA 5/12: loss=0.632009 nfev=15
#   Phase A (SV) | outer 1/4 mb 3/4 (statevector) SPSA 6/12: loss=0.631457 nfev=18
#   Phase A (SV) | outer 1/4 mb 3/4 (statevector) SPSA 7/12: loss=0.631592 nfev=21
#   Phase A (SV) | outer 1/4 mb 3/4 (statevector) SPSA 8/12: loss=0.635440 nfev=24
#   Phase A (SV) | outer 1/4 mb 3/4 (statevector) SPSA 9/12: loss=0.632633 nfev=27
#   Phase A (SV) | outer 1/4 mb 3/4 (statevector) SPSA 10/12: loss=0.636694 nfev=30
#   Phase A (SV) | outer 1/4 mb 3/4 (statevector) SPSA 11/12: loss=0.634692 nfev=33
#   Phase A (SV) | outer 1/4 mb 3/4 (statevector) SPSA 12/12: loss=0.632598 nfev=36
#   Phase A (SV) | outer 1/4 mb 3/4 (statevector) done nit=12 nfev=36
#   Phase A (SV) | outer 1/4 mb 4/4 (statevector) SPSA 1/12: loss=0.724570 nfev=3
#   Phase A (SV) | outer 1/4 mb 4/4 (statevector) SPSA 2/12: loss=0.724206 nfev=6
#   Phase A (SV) | outer 1/4 mb 4/4 (statevector) SPSA 3/12: loss=0.714947 nfev=9
#   Phase A (SV) | outer 1/4 mb 4/4 (statevector) SPSA 4/12: loss=0.707278 nfev=12
#   Phase A (SV) | outer 1/4 mb 4/4 (statevector) SPSA 5/12: loss=0.715306 nfev=15
#   Phase A (SV) | outer 1/4 mb 4/4 (statevector) SPSA 6/12: loss=0.707742 nfev=18
#   Phase A (SV) | outer 1/4 mb 4/4 (statevector) SPSA 7/12: loss=0.701613 nfev=21
#   Phase A (SV) | outer 1/4 mb 4/4 (statevector) SPSA 8/12: loss=0.703475 nfev=24
#   Phase A (SV) | outer 1/4 mb 4/4 (statevector) SPSA 9/12: loss=0.706809 nfev=27
#   Phase A (SV) | outer 1/4 mb 4/4 (statevector) SPSA 10/12: loss=0.699708 nfev=30
#   Phase A (SV) | outer 1/4 mb 4/4 (statevector) SPSA 11/12: loss=0.706205 nfev=33
#   Phase A (SV) | outer 1/4 mb 4/4 (statevector) SPSA 12/12: loss=0.708349 nfev=36
#   Phase A (SV) | outer 1/4 mb 4/4 (statevector) done nit=12 nfev=36
#   Phase A (SV) | outer 2/4 mb 1/4 (statevector) SPSA 1/12: loss=0.614998 nfev=3
#   Phase A (SV) | outer 2/4 mb 1/4 (statevector) SPSA 2/12: loss=0.616786 nfev=6
#   Phase A (SV) | outer 2/4 mb 1/4 (statevector) SPSA 3/12: loss=0.604130 nfev=9
#   Phase A (SV) | outer 2/4 mb 1/4 (statevector) SPSA 4/12: loss=0.611795 nfev=12
#   Phase A (SV) | outer 2/4 mb 1/4 (statevector) SPSA 5/12: loss=0.613789 nfev=15
#   Phase A (SV) | outer 2/4 mb 1/4 (statevector) SPSA 6/12: loss=0.622332 nfev=18
#   Phase A (SV) | outer 2/4 mb 1/4 (statevector) SPSA 7/12: loss=0.614234 nfev=21
#   Phase A (SV) | outer 2/4 mb 1/4 (statevector) SPSA 8/12: loss=0.622444 nfev=24
#   Phase A (SV) | outer 2/4 mb 1/4 (statevector) SPSA 9/12: loss=0.619346 nfev=27
#   Phase A (SV) | outer 2/4 mb 1/4 (statevector) SPSA 10/12: loss=0.604827 nfev=30
#   Phase A (SV) | outer 2/4 mb 1/4 (statevector) SPSA 11/12: loss=0.610862 nfev=33
#   Phase A (SV) | outer 2/4 mb 1/4 (statevector) SPSA 12/12: loss=0.606704 nfev=36
#   Phase A (SV) | outer 2/4 mb 1/4 (statevector) done nit=12 nfev=36
#   Phase A (SV) | outer 2/4 mb 2/4 (statevector) SPSA 1/12: loss=0.521355 nfev=3
#   Phase A (SV) | outer 2/4 mb 2/4 (statevector) SPSA 2/12: loss=0.509675 nfev=6
#   Phase A (SV) | outer 2/4 mb 2/4 (statevector) SPSA 3/12: loss=0.513399 nfev=9
#   Phase A (SV) | outer 2/4 mb 2/4 (statevector) SPSA 4/12: loss=0.504426 nfev=12
#   Phase A (SV) | outer 2/4 mb 2/4 (statevector) SPSA 5/12: loss=0.518501 nfev=15
#   Phase A (SV) | outer 2/4 mb 2/4 (statevector) SPSA 6/12: loss=0.505302 nfev=18
#   Phase A (SV) | outer 2/4 mb 2/4 (statevector) SPSA 7/12: loss=0.507467 nfev=21
#   Phase A (SV) | outer 2/4 mb 2/4 (statevector) SPSA 8/12: loss=0.513518 nfev=24
#   Phase A (SV) | outer 2/4 mb 2/4 (statevector) SPSA 9/12: loss=0.512511 nfev=27
#   Phase A (SV) | outer 2/4 mb 2/4 (statevector) SPSA 10/12: loss=0.509134 nfev=30
#   Phase A (SV) | outer 2/4 mb 2/4 (statevector) SPSA 11/12: loss=0.502443 nfev=33
#   Phase A (SV) | outer 2/4 mb 2/4 (statevector) SPSA 12/12: loss=0.512994 nfev=36
#   Phase A (SV) | outer 2/4 mb 2/4 (statevector) done nit=12 nfev=36
#   Phase A (SV) | outer 2/4 mb 3/4 (statevector) SPSA 1/12: loss=0.497146 nfev=3
#   Phase A (SV) | outer 2/4 mb 3/4 (statevector) SPSA 2/12: loss=0.503200 nfev=6
#   Phase A (SV) | outer 2/4 mb 3/4 (statevector) SPSA 3/12: loss=0.495147 nfev=9
#   Phase A (SV) | outer 2/4 mb 3/4 (statevector) SPSA 4/12: loss=0.502627 nfev=12
#   Phase A (SV) | outer 2/4 mb 3/4 (statevector) SPSA 5/12: loss=0.507813 nfev=15
#   Phase A (SV) | outer 2/4 mb 3/4 (statevector) SPSA 6/12: loss=0.496509 nfev=18
#   Phase A (SV) | outer 2/4 mb 3/4 (statevector) SPSA 7/12: loss=0.495314 nfev=21
#   Phase A (SV) | outer 2/4 mb 3/4 (statevector) SPSA 8/12: loss=0.491123 nfev=24
#   Phase A (SV) | outer 2/4 mb 3/4 (statevector) SPSA 9/12: loss=0.488235 nfev=27
#   Phase A (SV) | outer 2/4 mb 3/4 (statevector) SPSA 10/12: loss=0.498609 nfev=30
#   Phase A (SV) | outer 2/4 mb 3/4 (statevector) SPSA 11/12: loss=0.491947 nfev=33
#   Phase A (SV) | outer 2/4 mb 3/4 (statevector) SPSA 12/12: loss=0.493324 nfev=36
#   Phase A (SV) | outer 2/4 mb 3/4 (statevector) done nit=12 nfev=36
#   Phase A (SV) | outer 2/4 mb 4/4 (statevector) SPSA 1/12: loss=0.575027 nfev=3
#   Phase A (SV) | outer 2/4 mb 4/4 (statevector) SPSA 2/12: loss=0.569621 nfev=6
#   Phase A (SV) | outer 2/4 mb 4/4 (statevector) SPSA 3/12: loss=0.582012 nfev=9
#   Phase A (SV) | outer 2/4 mb 4/4 (statevector) SPSA 4/12: loss=0.575624 nfev=12
#   Phase A (SV) | outer 2/4 mb 4/4 (statevector) SPSA 5/12: loss=0.567694 nfev=15
#   Phase A (SV) | outer 2/4 mb 4/4 (statevector) SPSA 6/12: loss=0.564860 nfev=18
#   Phase A (SV) | outer 2/4 mb 4/4 (statevector) SPSA 7/12: loss=0.565098 nfev=21
#   Phase A (SV) | outer 2/4 mb 4/4 (statevector) SPSA 8/12: loss=0.580618 nfev=24
#   Phase A (SV) | outer 2/4 mb 4/4 (statevector) SPSA 9/12: loss=0.573474 nfev=27
#   Phase A (SV) | outer 2/4 mb 4/4 (statevector) SPSA 10/12: loss=0.579193 nfev=30
#   Phase A (SV) | outer 2/4 mb 4/4 (statevector) SPSA 11/12: loss=0.572043 nfev=33
#   Phase A (SV) | outer 2/4 mb 4/4 (statevector) SPSA 12/12: loss=0.574556 nfev=36
#   Phase A (SV) | outer 2/4 mb 4/4 (statevector) done nit=12 nfev=36
#   Phase A (SV) | outer 3/4 mb 1/4 (statevector) SPSA 1/12: loss=0.623293 nfev=3
#   Phase A (SV) | outer 3/4 mb 1/4 (statevector) SPSA 2/12: loss=0.630030 nfev=6
#   Phase A (SV) | outer 3/4 mb 1/4 (statevector) SPSA 3/12: loss=0.631437 nfev=9
#   Phase A (SV) | outer 3/4 mb 1/4 (statevector) SPSA 4/12: loss=0.627533 nfev=12
#   Phase A (SV) | outer 3/4 mb 1/4 (statevector) SPSA 5/12: loss=0.622055 nfev=15
#   Phase A (SV) | outer 3/4 mb 1/4 (statevector) SPSA 6/12: loss=0.628769 nfev=18
#   Phase A (SV) | outer 3/4 mb 1/4 (statevector) SPSA 7/12: loss=0.615522 nfev=21
#   Phase A (SV) | outer 3/4 mb 1/4 (statevector) SPSA 8/12: loss=0.623611 nfev=24
#   Phase A (SV) | outer 3/4 mb 1/4 (statevector) SPSA 9/12: loss=0.622504 nfev=27
#   Phase A (SV) | outer 3/4 mb 1/4 (statevector) SPSA 10/12: loss=0.639052 nfev=30
#   Phase A (SV) | outer 3/4 mb 1/4 (statevector) SPSA 11/12: loss=0.621950 nfev=33
#   Phase A (SV) | outer 3/4 mb 1/4 (statevector) SPSA 12/12: loss=0.622583 nfev=36
#   Phase A (SV) | outer 3/4 mb 1/4 (statevector) done nit=12 nfev=36
#   Phase A (SV) | outer 3/4 mb 2/4 (statevector) SPSA 1/12: loss=0.601006 nfev=3
#   Phase A (SV) | outer 3/4 mb 2/4 (statevector) SPSA 2/12: loss=0.593348 nfev=6
#   Phase A (SV) | outer 3/4 mb 2/4 (statevector) SPSA 3/12: loss=0.607961 nfev=9
#   Phase A (SV) | outer 3/4 mb 2/4 (statevector) SPSA 4/12: loss=0.592451 nfev=12
#   Phase A (SV) | outer 3/4 mb 2/4 (statevector) SPSA 5/12: loss=0.606403 nfev=15
#   Phase A (SV) | outer 3/4 mb 2/4 (statevector) SPSA 6/12: loss=0.607603 nfev=18
#   Phase A (SV) | outer 3/4 mb 2/4 (statevector) SPSA 7/12: loss=0.601021 nfev=21
#   Phase A (SV) | outer 3/4 mb 2/4 (statevector) SPSA 8/12: loss=0.600225 nfev=24
#   Phase A (SV) | outer 3/4 mb 2/4 (statevector) SPSA 9/12: loss=0.601845 nfev=27
#   Phase A (SV) | outer 3/4 mb 2/4 (statevector) SPSA 10/12: loss=0.594415 nfev=30
#   Phase A (SV) | outer 3/4 mb 2/4 (statevector) SPSA 11/12: loss=0.600116 nfev=33
#   Phase A (SV) | outer 3/4 mb 2/4 (statevector) SPSA 12/12: loss=0.587761 nfev=36
#   Phase A (SV) | outer 3/4 mb 2/4 (statevector) done nit=12 nfev=36
#   Phase A (SV) | outer 3/4 mb 3/4 (statevector) SPSA 1/12: loss=0.783636 nfev=3
#   Phase A (SV) | outer 3/4 mb 3/4 (statevector) SPSA 2/12: loss=0.738557 nfev=6
#   Phase A (SV) | outer 3/4 mb 3/4 (statevector) SPSA 3/12: loss=0.737010 nfev=9
#   Phase A (SV) | outer 3/4 mb 3/4 (statevector) SPSA 4/12: loss=0.714113 nfev=12
#   Phase A (SV) | outer 3/4 mb 3/4 (statevector) SPSA 5/12: loss=0.711573 nfev=15
#   Phase A (SV) | outer 3/4 mb 3/4 (statevector) SPSA 6/12: loss=0.712278 nfev=18
#   Phase A (SV) | outer 3/4 mb 3/4 (statevector) SPSA 7/12: loss=0.701292 nfev=21
#   Phase A (SV) | outer 3/4 mb 3/4 (statevector) SPSA 8/12: loss=0.707066 nfev=24
#   Phase A (SV) | outer 3/4 mb 3/4 (statevector) SPSA 9/12: loss=0.682833 nfev=27
#   Phase A (SV) | outer 3/4 mb 3/4 (statevector) SPSA 10/12: loss=0.701195 nfev=30
#   Phase A (SV) | outer 3/4 mb 3/4 (statevector) SPSA 11/12: loss=0.694238 nfev=33
#   Phase A (SV) | outer 3/4 mb 3/4 (statevector) SPSA 12/12: loss=0.698217 nfev=36
#   Phase A (SV) | outer 3/4 mb 3/4 (statevector) done nit=12 nfev=36
#   Phase A (SV) | outer 3/4 mb 4/4 (statevector) SPSA 1/12: loss=0.765454 nfev=3
#   Phase A (SV) | outer 3/4 mb 4/4 (statevector) SPSA 2/12: loss=0.753431 nfev=6
#   Phase A (SV) | outer 3/4 mb 4/4 (statevector) SPSA 3/12: loss=0.738204 nfev=9
#   Phase A (SV) | outer 3/4 mb 4/4 (statevector) SPSA 4/12: loss=0.724197 nfev=12
#   Phase A (SV) | outer 3/4 mb 4/4 (statevector) SPSA 5/12: loss=0.722366 nfev=15
#   Phase A (SV) | outer 3/4 mb 4/4 (statevector) SPSA 6/12: loss=0.723822 nfev=18
#   Phase A (SV) | outer 3/4 mb 4/4 (statevector) SPSA 7/12: loss=0.733600 nfev=21
#   Phase A (SV) | outer 3/4 mb 4/4 (statevector) SPSA 8/12: loss=0.723971 nfev=24
#   Phase A (SV) | outer 3/4 mb 4/4 (statevector) SPSA 9/12: loss=0.713901 nfev=27
#   Phase A (SV) | outer 3/4 mb 4/4 (statevector) SPSA 10/12: loss=0.717707 nfev=30
#   Phase A (SV) | outer 3/4 mb 4/4 (statevector) SPSA 11/12: loss=0.717540 nfev=33
#   Phase A (SV) | outer 3/4 mb 4/4 (statevector) SPSA 12/12: loss=0.705654 nfev=36
#   Phase A (SV) | outer 3/4 mb 4/4 (statevector) done nit=12 nfev=36
#   Phase A (SV) | outer 4/4 mb 1/4 (statevector) SPSA 1/12: loss=0.679369 nfev=3
#   Phase A (SV) | outer 4/4 mb 1/4 (statevector) SPSA 2/12: loss=0.678552 nfev=6
#   Phase A (SV) | outer 4/4 mb 1/4 (statevector) SPSA 3/12: loss=0.669841 nfev=9
#   Phase A (SV) | outer 4/4 mb 1/4 (statevector) SPSA 4/12: loss=0.676152 nfev=12
#   Phase A (SV) | outer 4/4 mb 1/4 (statevector) SPSA 5/12: loss=0.684706 nfev=15
#   Phase A (SV) | outer 4/4 mb 1/4 (statevector) SPSA 6/12: loss=0.680369 nfev=18
#   Phase A (SV) | outer 4/4 mb 1/4 (statevector) SPSA 7/12: loss=0.673669 nfev=21
#   Phase A (SV) | outer 4/4 mb 1/4 (statevector) SPSA 8/12: loss=0.674322 nfev=24
#   Phase A (SV) | outer 4/4 mb 1/4 (statevector) SPSA 9/12: loss=0.673103 nfev=27
#   Phase A (SV) | outer 4/4 mb 1/4 (statevector) SPSA 10/12: loss=0.674185 nfev=30
#   Phase A (SV) | outer 4/4 mb 1/4 (statevector) SPSA 11/12: loss=0.676695 nfev=33
#   Phase A (SV) | outer 4/4 mb 1/4 (statevector) SPSA 12/12: loss=0.669017 nfev=36
#   Phase A (SV) | outer 4/4 mb 1/4 (statevector) done nit=12 nfev=36
#   Phase A (SV) | outer 4/4 mb 2/4 (statevector) SPSA 1/12: loss=0.536561 nfev=3
#   Phase A (SV) | outer 4/4 mb 2/4 (statevector) SPSA 2/12: loss=0.532625 nfev=6
#   Phase A (SV) | outer 4/4 mb 2/4 (statevector) SPSA 3/12: loss=0.524340 nfev=9
#   Phase A (SV) | outer 4/4 mb 2/4 (statevector) SPSA 4/12: loss=0.533750 nfev=12
#   Phase A (SV) | outer 4/4 mb 2/4 (statevector) SPSA 5/12: loss=0.523771 nfev=15
#   Phase A (SV) | outer 4/4 mb 2/4 (statevector) SPSA 6/12: loss=0.519145 nfev=18
#   Phase A (SV) | outer 4/4 mb 2/4 (statevector) SPSA 7/12: loss=0.523855 nfev=21
#   Phase A (SV) | outer 4/4 mb 2/4 (statevector) SPSA 8/12: loss=0.519511 nfev=24
#   Phase A (SV) | outer 4/4 mb 2/4 (statevector) SPSA 9/12: loss=0.523654 nfev=27
#   Phase A (SV) | outer 4/4 mb 2/4 (statevector) SPSA 10/12: loss=0.519188 nfev=30
#   Phase A (SV) | outer 4/4 mb 2/4 (statevector) SPSA 11/12: loss=0.516583 nfev=33
#   Phase A (SV) | outer 4/4 mb 2/4 (statevector) SPSA 12/12: loss=0.524027 nfev=36
#   Phase A (SV) | outer 4/4 mb 2/4 (statevector) done nit=12 nfev=36
#   Phase A (SV) | outer 4/4 mb 3/4 (statevector) SPSA 1/12: loss=0.603998 nfev=3
#   Phase A (SV) | outer 4/4 mb 3/4 (statevector) SPSA 2/12: loss=0.606936 nfev=6
#   Phase A (SV) | outer 4/4 mb 3/4 (statevector) SPSA 3/12: loss=0.594631 nfev=9
#   Phase A (SV) | outer 4/4 mb 3/4 (statevector) SPSA 4/12: loss=0.603288 nfev=12
#   Phase A (SV) | outer 4/4 mb 3/4 (statevector) SPSA 5/12: loss=0.607654 nfev=15
#   Phase A (SV) | outer 4/4 mb 3/4 (statevector) SPSA 6/12: loss=0.599344 nfev=18
#   Phase A (SV) | outer 4/4 mb 3/4 (statevector) SPSA 7/12: loss=0.589054 nfev=21
#   Phase A (SV) | outer 4/4 mb 3/4 (statevector) SPSA 8/12: loss=0.602787 nfev=24
#   Phase A (SV) | outer 4/4 mb 3/4 (statevector) SPSA 9/12: loss=0.590106 nfev=27
#   Phase A (SV) | outer 4/4 mb 3/4 (statevector) SPSA 10/12: loss=0.588822 nfev=30
#   Phase A (SV) | outer 4/4 mb 3/4 (statevector) SPSA 11/12: loss=0.595902 nfev=33
#   Phase A (SV) | outer 4/4 mb 3/4 (statevector) SPSA 12/12: loss=0.597642 nfev=36
#   Phase A (SV) | outer 4/4 mb 3/4 (statevector) done nit=12 nfev=36
#   Phase A (SV) | outer 4/4 mb 4/4 (statevector) SPSA 1/12: loss=0.577900 nfev=3
#   Phase A (SV) | outer 4/4 mb 4/4 (statevector) SPSA 2/12: loss=0.582667 nfev=6
#   Phase A (SV) | outer 4/4 mb 4/4 (statevector) SPSA 3/12: loss=0.576686 nfev=9
#   Phase A (SV) | outer 4/4 mb 4/4 (statevector) SPSA 4/12: loss=0.581268 nfev=12
#   Phase A (SV) | outer 4/4 mb 4/4 (statevector) SPSA 5/12: loss=0.571722 nfev=15
#   Phase A (SV) | outer 4/4 mb 4/4 (statevector) SPSA 6/12: loss=0.569204 nfev=18
#   Phase A (SV) | outer 4/4 mb 4/4 (statevector) SPSA 7/12: loss=0.572245 nfev=21
#   Phase A (SV) | outer 4/4 mb 4/4 (statevector) SPSA 8/12: loss=0.577495 nfev=24
#   Phase A (SV) | outer 4/4 mb 4/4 (statevector) SPSA 9/12: loss=0.568106 nfev=27
#   Phase A (SV) | outer 4/4 mb 4/4 (statevector) SPSA 10/12: loss=0.570711 nfev=30
#   Phase A (SV) | outer 4/4 mb 4/4 (statevector) SPSA 11/12: loss=0.574009 nfev=33
#   Phase A (SV) | outer 4/4 mb 4/4 (statevector) SPSA 12/12: loss=0.568463 nfev=36
#   Phase A (SV) | outer 4/4 mb 4/4 (statevector) done nit=12 nfev=36
# Saved statevector-trained weights to /Users/jkw/Documents/uni/axion/QC1/tests/model_odra_iqm_exp_weights_sv.npy
# Statevector snapshot on test (exact): loss=0.779199 acc=0.6436 f1=0.3718 f1_macro=0.5615

# %% [markdown]
# ## Phase B — IQM test metrics **before** IQM fine-tuning (same weights as Phase A)

# %%
print(f"Phase B starting at {SESSION_T_UTC} (see build cell for live connect time)")
metrics_iqm_before = evaluate_iqm_repeated(
    weights_sv,
    X_test,
    y_test,
    "Phase B — IQM test BEFORE fine-tune",
    n_repeats=IQM_TEST_REPEATS,
)
# Out:
# Phase B starting at 2026-03-22 14:31:40 UTC (see build cell for live connect time)
#     -> loss=0.779462 acc=0.6436 f1=0.3718 f1_macro=0.5615 [proxy: StatevectorEstimator]
#     -> loss=0.780150 acc=0.6364 f1=0.3506 f1_macro=0.5491 [proxy: StatevectorEstimator]
#     -> loss=0.775663 acc=0.6436 f1=0.3718 f1_macro=0.5615 [proxy: StatevectorEstimator]
#     -> loss=0.778885 acc=0.6400 f1=0.3613 f1_macro=0.5553 [proxy: StatevectorEstimator]
#     -> loss=0.774236 acc=0.6436 f1=0.3718 f1_macro=0.5615 [proxy: StatevectorEstimator]
# Phase B — IQM test BEFORE fine-tune AGG mean±std: loss=0.777679±0.002582 acc=0.6415±0.0033 f1=0.3655±0.0094 f1_macro=0.5578±0.0056

# %% [markdown]
# ## Phase C — SPSA fine-tuning with **IQM minibatch MSE** (starts from `weights_sv`)

# %%
if SMOKE_TEST:
    print("SMOKE_TEST: skipping true IQM fine-tune; keeping Phase A weights as final.")
    weights_after = weights_sv.copy()
    ft_meta = {"note": "smoke: no IQM fine-tune"}
else:
    weights_after, ft_meta = run_iqm_finetune_early_stop(weights_sv, rng)

np.save(WEIGHTS_FINAL, weights_after)
print("Saved final weights to", WEIGHTS_FINAL)
print("Phase C meta:", ft_meta)
# Out:
# SMOKE_TEST: skipping true IQM fine-tune; keeping Phase A weights as final.
# Saved final weights to /Users/jkw/Documents/uni/axion/QC1/tests/model_odra_iqm_exp_weights_after_iqm_ft.npy
# Phase C meta: {'note': 'smoke: no IQM fine-tune'}

# %% [markdown]
# ## Phase D — IQM test metrics **after** fine-tuning + comparison

# %%
metrics_iqm_after = evaluate_iqm_repeated(
    weights_after,
    X_test,
    y_test,
    "Phase D — IQM test AFTER fine-tune",
    n_repeats=IQM_TEST_REPEATS,
)

metrics_sv_after_exact = metrics_from_preds(predict_raw_sv(weights_after, X_test), y_test)

rows = [
    {
        "stage": "IQM test @ weights after Phase A (SV-only train)",
        "loss": metrics_iqm_before["loss_mean"],
        "loss_std": metrics_iqm_before["loss_std"],
        "acc": metrics_iqm_before["acc_mean"],
        "acc_std": metrics_iqm_before["acc_std"],
        "f1": metrics_iqm_before["f1_mean"],
        "f1_std": metrics_iqm_before["f1_std"],
        "f1_macro": metrics_iqm_before["f1_macro_mean"],
        "f1_macro_std": metrics_iqm_before["f1_macro_std"],
        "note": metrics_iqm_before.get("note", ""),
    },
    {
        "stage": "IQM test @ weights after Phase C (IQM fine-tune)",
        "loss": metrics_iqm_after["loss_mean"],
        "loss_std": metrics_iqm_after["loss_std"],
        "acc": metrics_iqm_after["acc_mean"],
        "acc_std": metrics_iqm_after["acc_std"],
        "f1": metrics_iqm_after["f1_mean"],
        "f1_std": metrics_iqm_after["f1_std"],
        "f1_macro": metrics_iqm_after["f1_macro_mean"],
        "f1_macro_std": metrics_iqm_after["f1_macro_std"],
        "note": metrics_iqm_after.get("note", ""),
    },
    {
        "stage": "Exact statevector test (final weights)",
        "loss": metrics_sv_after_exact["loss"],
        "loss_std": 0.0,
        "acc": metrics_sv_after_exact["acc"],
        "acc_std": 0.0,
        "f1": metrics_sv_after_exact["f1"],
        "f1_std": 0.0,
        "f1_macro": metrics_sv_after_exact["f1_macro"],
        "f1_macro_std": 0.0,
        "note": "StatevectorEstimator",
    },
]
df = pd.DataFrame(rows)
print(df.to_string(index=False))

delta_acc = metrics_iqm_after["acc_mean"] - metrics_iqm_before["acc_mean"]
delta_f1 = metrics_iqm_after["f1_mean"] - metrics_iqm_before["f1_mean"]
delta_fm = metrics_iqm_after["f1_macro_mean"] - metrics_iqm_before["f1_macro_mean"]
print(f"Δ IQM test acc (mean, after - before): {delta_acc:+.4f}")
print(f"Δ IQM test F1 (mean, after - before): {delta_f1:+.4f}")
print(f"Δ IQM test F1_macro (mean, after - before): {delta_fm:+.4f}")

fig, ax = plt.subplots(figsize=(8, 4))
stages = ["IQM\nbefore FT", "IQM\nafter FT"]
x = np.arange(len(stages))
w = 0.25
ax.bar(x - w, [metrics_iqm_before["acc_mean"], metrics_iqm_after["acc_mean"]], w, label="Acc (mean)")
ax.bar(x, [metrics_iqm_before["f1_mean"], metrics_iqm_after["f1_mean"]], w, label="F1 +1 (mean)")
ax.bar(x + w, [metrics_iqm_before["f1_macro_mean"], metrics_iqm_after["f1_macro_mean"]], w, label="F1 macro (mean)")
ax.set_xticks(x)
ax.set_xticklabels(stages)
ax.set_ylim(0, 1)
ax.set_ylabel("Score")
ax.set_title("IQM full test — means (error bars from repeated evals)")
# error bars
ax.errorbar(
    x - w,
    [metrics_iqm_before["acc_mean"], metrics_iqm_after["acc_mean"]],
    yerr=[metrics_iqm_before["acc_std"], metrics_iqm_after["acc_std"]],
    fmt="none",
    ecolor="k",
    capsize=3,
)
ax.errorbar(
    x,
    [metrics_iqm_before["f1_mean"], metrics_iqm_after["f1_mean"]],
    yerr=[metrics_iqm_before["f1_std"], metrics_iqm_after["f1_std"]],
    fmt="none",
    ecolor="k",
    capsize=3,
)
ax.errorbar(
    x + w,
    [metrics_iqm_before["f1_macro_mean"], metrics_iqm_after["f1_macro_mean"]],
    yerr=[metrics_iqm_before["f1_macro_std"], metrics_iqm_after["f1_macro_std"]],
    fmt="none",
    ecolor="k",
    capsize=3,
)
ax.legend()
ax.grid(True, axis="y", alpha=0.3)
plt.tight_layout()
plt.show()

fig2, axes = plt.subplots(1, 2, figsize=(10, 4))
cm_b = confusion_matrix(y_test, metrics_iqm_before["cls_pred"], labels=[-1, 1])
cm_a = confusion_matrix(y_test, metrics_iqm_after["cls_pred"], labels=[-1, 1])
ConfusionMatrixDisplay(cm_b, display_labels=[-1, 1]).plot(ax=axes[0], colorbar=False)
axes[0].set_title("IQM confusion — before FT (mean ⟨Z⟩ over repeats)")
ConfusionMatrixDisplay(cm_a, display_labels=[-1, 1]).plot(ax=axes[1], colorbar=False)
axes[1].set_title("IQM confusion — after FT (mean ⟨Z⟩ over repeats)")
plt.tight_layout()
plt.show()
# Out:
#     -> loss=0.776473 acc=0.6473 f1=0.3822 f1_macro=0.5677 [proxy: StatevectorEstimator]
#     -> loss=0.780578 acc=0.6400 f1=0.3613 f1_macro=0.5553 [proxy: StatevectorEstimator]
#     -> loss=0.776434 acc=0.6436 f1=0.3718 f1_macro=0.5615 [proxy: StatevectorEstimator]
#     -> loss=0.777922 acc=0.6436 f1=0.3718 f1_macro=0.5615 [proxy: StatevectorEstimator]
#     -> loss=0.779980 acc=0.6364 f1=0.3506 f1_macro=0.5491 [proxy: StatevectorEstimator]
# Phase D — IQM test AFTER fine-tune AGG mean±std: loss=0.778277±0.001935 acc=0.6422±0.0041 f1=0.3675±0.0120 f1_macro=0.5590±0.0071
#                                            stage     loss  loss_std      acc  acc_std       f1   f1_std  f1_macro  f1_macro_std                                                  note
# IQM test @ weights after Phase A (SV-only train) 0.777679  0.002582 0.641455 0.003252 0.365465 0.009449  0.557797      0.005573 proxy: StatevectorEstimator (repeated runs identical)
# IQM test @ weights after Phase C (IQM fine-tune) 0.778277  0.001935 0.642182 0.004146 0.367539 0.011984  0.559026      0.007076 proxy: StatevectorEstimator (repeated runs identical)
#           Exact statevector test (final weights) 0.778347  0.000000 0.640000 0.000000 0.361290 0.000000  0.555329      0.000000                                  StatevectorEstimator
# Δ IQM test acc (mean, after - before): +0.0007
# Δ IQM test F1 (mean, after - before): +0.0021
# Δ IQM test F1_macro (mean, after - before): +0.0012
